# %% [markdown]
# ## Restaurant Seat Optimization
#
#
#
#
# #### Step 0: Obtain parameters from 'data.txt'

# %%
import json

w = l = customer_goodwill = REVENUE_GOAL = num_timeslots = randomly_generated_data = 0
marginal_revenue = {}

with open('../data.json') as f:
    data = json.load(f)
    w = data['restaurant_width']
    l = data['restaurant_length']
    customer_goodwill = data['customer_goodwill']
    REVENUE_GOAL = data['revenue_goal']
    randomly_generated_data = data['randomly_generated_data']
    max_party_size = data['max_party_size']
    for i in data['marginal_revenue']:
        marginal_revenue[int(i)] = data['marginal_revenue'][i]

# %% [markdown]
# #### Step 1: Import gurobipy module

# %%
import gurobipy as gp
from gurobipy import GRB
import random

# %% [markdown]
# #### Step 2: Define your model

# %%
m = gp.Model()
# Out:
# Using license file /Users/matthewfollegot/gurobi.lic
# Academic license - for non-commercial use only

# %% [markdown]
# #### Step 3: Define your sets

# %%
# set of timeslots
K = 7

# set of parties at each timeslot
# since there are 7 timeslots and since this data is randomly generated, 
# the set of parties during timelsot k will be I[k].
# Prior to having randomly generated demand we had set I = 40 (40 parties) for each timeslot
if randomly_generated_data == True:
    I = [
        random.randint(10,15), 
        random.randint(17,24),
        random.randint(17,24),
        random.randint(10,15),
        random.randint(25,40),
        random.randint(25,40),
        random.randint(10,15),
    ]

else:
    print("Please allow data to be randomly generated to ensure accuracy and reliability of resutls")

# %% [markdown]
# #### Step 4: Define your parameters

# %%
#initializing the party 
party_size = {}
for k in range(K):
    for i in range(I[k]):
        party_size[i, k] = random.randint(2,max_party_size)

# the table mapping below represents
# how many tables a specific party_size would require
table_mapping = {}
for i in range(2,max_party_size + 1):
    table_mapping[i] = i // 2 + i % 2

# initializing the amount of space that each of the party sizes 
# would take up
space = {}
for k in range(K):
    for i in range(I[k]):
        num_tables = table_mapping.get(party_size[i, k])
        space[i, k] = 6 + 3 * num_tables

# %% [markdown]
# #### Step 5: Define your decision variables

# %%
# defining xik, whethere or not party i is seated at timeslot k
x = {}
for k in range(K):
    for i in range(I[k]):
        x[i,k] = m.addVar(lb=0.0, vtype=GRB.BINARY, name="x_"+str(i)+str(k))
        
# defining bk, whether or not there is a social distancing violation at timeslot k
b = {}
for k in range(K):
    b[k] = m.addVar(lb=0.0, obj=880, vtype=GRB.BINARY, name="b_"+str(k))
    
# defining the piecewise function for revenue
# model.setPWLObj()
s = {}
#defining space slack variable
for k in range(K):
    s[k] = m.addVar(lb=0.0, vtype=GRB.INTEGER, name="s_"+str(k))

#defining space excess variable
e = {}
for k in range(K):
    e[k] = m.addVar(lb=0.0, vtype=GRB.INTEGER, name="e_" + str(k))

u = {}
#defining seating everyone slack variable
for k in range(K):
    u[k] = m.addVar(lb=0.0, obj=customer_goodwill, vtype=GRB.INTEGER, name="u_"+str(k))

# %% [markdown]
# #### Step 6: Set your objective function

# %%
m.modelSense = GRB.MINIMIZE

# %% [markdown]
# #### Step 7: Add Constraints

# %%
# defining space constraint
for k in range(K):
    running_sum = 0
    for i in range(I[k]):
        #print(running_sum)
        #xik = m.getVarByName("x_"+str(i) + str(k)).X
        #print(xik)
#         spaceik = space[i,k]
        running_sum += x[i,k]*space[i,k]
#    print(running_sum)
    m.addConstr((s[k] - e[k] + running_sum), GRB.EQUAL, l*w)

print(f"l={l}, w={w}")
    
# defining the constraint that turns on the social distancing violated binary var
for k in range(K):
    m.addConstr(10**6*b[k], GRB.GREATER_EQUAL, e[k])

# defining the constraint that makes sure that if there are social distancing violations,
# they take up at most 20% of the dining room
for k in range(K):
    m.addConstr(e[k], GRB.LESS_EQUAL, l * w * 0.2)
    
# defining the constraint that makes sure that each party only occupies one table
for k in range(K):
    for i in range(I[k]):
        m.addConstr(x[i,k], GRB.LESS_EQUAL, 1)

# goal constraint of seating everyone in the restaurant
for k in range(K):
    total = 0
    seated = 0
    for i in range(I[k]):
        total += party_size[i,k]
        seated += party_size[i,k]*x[i,k]
    m.addConstr(seated + u[k], GRB.EQUAL, total)

        
        
# for k in range(K):
#     m.addConstr(s[k], GRB.LESS_EQUAL, l*w*0.2)
    
m.update()
# Out:
# l=20, w=20

# %% [markdown]
# #### Step 8: Solve the model

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (mac64)
# Optimize a model with 170 rows, 170 columns and 468 nonzeros
# Model fingerprint: 0xd432672c
# Variable types: 0 continuous, 170 integer (149 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+06]
#   Objective range  [1e+02, 9e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 74700.000000
# Presolve removed 169 rows and 162 columns
# Presolve time: 0.01s
# Presolved: 1 rows, 8 columns, 8 nonzeros
# Found heuristic solution: objective 7980.0000000
# Variable types: 0 continuous, 8 integer (1 binary)
#
# Root relaxation: objective 4.160000e+03, 1 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4160.0000000 4160.00000  0.00%     -    0s
#
# Explored 0 nodes (1 simplex iterations) in 0.13 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 4160 7980 74700
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.160000000000e+03, best bound 4.160000000000e+03, gap 0.0000%

# %% [markdown]
# #### Step 8: Print variable values  (The Messy Way)

# %%
print("Printing result\n")
print('\nProfit: %g' % m.objVal) #gets the objective function value
print('\nSOLUTION')
for myVars in m.getVars():
    #print(myVars)
    print('%s %g' % (myVars.varName, myVars.x))
# Out:
# Printing result
#
#
# Profit: 4160
#
# SOLUTION
# x_00 1
# x_10 1
# x_20 1
# x_30 1
# x_40 1
# x_50 1
# x_60 1
# x_70 1
# x_80 1
# x_90 1
# x_100 1
# x_01 1
# x_11 1
# x_21 1
# x_31 1
# x_41 1
# x_51 1
# x_61 1
# x_71 1
# x_81 1
# x_91 1
# x_101 1
# x_111 1
# x_121 1
# x_131 1
# x_141 1
# x_151 1
# x_161 1
# x_02 1
# x_12 1
# x_22 1
# x_32 1
# x_42 1
# x_52 1
# x_62 1
# x_72 1
# x_82 1
# x_92 1
# x_102 1
# x_112 1
# x_122 1
# x_132 1
# x_142 1
# x_152 1
# x_162 1
# x_172 1
# x_182 1
# x_192 1
# x_202 1
# x_03 1
# x_13 1
# x_23 1
# x_33 1
# x_43 1
# x_53 1
# x_63 1
# x_73 1
# x_83 1
# x_93 1
# x_04 -0
# x_14 0
# x_24 0
# x_34 1
# x_44 1
# x_54 0
# x_64 1
# x_74 1
# x_84 1
# x_94 1
# x_104 1
# x_114 1
# x_124 1
# x_134 1
# x_144 1
# x_154 0
# x_164 1
# x_174 1
# x_184 1
# x_194 0
# x_204 1
# x_214 1
# x_224 1
# x_234 0
# x_244 1
# x_254 0
# x_264 1
# x_274 1
# x_284 1
# x_294 1
# x_304 1
# x_314 1
# x_324 1
# x_334 1
# x_344 1
# x_354 1
# x_364 1
# x_374 1
# x_384 0
# x_394 1
# x_05 1
# x_15 1
# x_25 1
# x_35 1
# x_45 1
# x_55 1
# x_65 1
# x_75 1
# x_85 1
# x_95 1
# x_105 1
# x_115 1
# x_125 1
# x_135 1
# x_145 1
# x_155 -0
# x_165 1
# x_175 1
# x_185 1
# x_195 1
# x_205 1
# x_215 1
# x_225 1
# x_235 1
# x_245 1
# x_255 1
# x_265 1
# x_275 1
# x_285 1
# x_295 1
# x_305 1
# x_315 1
# x_325 1
# x_06 1
# x_16 1
# x_26 1
# x_36 1
# x_46 1
# x_56 1
# x_66 1
# x_76 1
# x_86 1
# x_96 1
# b_0 0
# b_1 0
# b_2 0
# b_3 0
# b_4 1
# b_5 1
# b_6 0
# s_0 247
# s_1 151
# s_2 91
# s_3 259
# s_4 0
# s_5 0
# s_6 253
# e_0 -0
# e_1 -0
# e_2 -0
# e_3 -0
# e_4 80
# e_5 80
# e_6 -0
# u_0 0
# u_1 0
# u_2 0
# u_3 0
# u_4 22
# u_5 2
# u_6 0

# %%
print('Model Summary\n\nRevenue less fines: %g' % m.objVal) #gets the objective function value

for k in range(K):
    res = ""
    if b[k].x != 1:
        res = "not"
    
    print(f"\nTimeslot {k+1}:\n")
    sum = 0
    for i in range(I[k]):
        if(x[i,k].x==1):
            sum += 1
            print(f"party {i+1} of size {party_size[i,k]} was seated")
        else:
            print(f"party {i+1} of size {party_size[i,k]} was not seated")

    print(f"\nPhysical distancing guideline {res} broken")
    print(f"Total number of parties seated during timeslot {k+1}: \t{sum} = {sum/I[k]*100:.2f}%")
    if b[k].x == 1:
        print(f"Amount of overoccupied space: {e[k].x}m^2\n")
    
    print(f"Amount of unoccupied space that can be allocated toward more customers: {s[k].x}m^2\n")
# Out:
# Model Summary
#
# Revenue less fines: 4160
#
# Timeslot 1:
#
# party 1 of size 2 was seated
# party 2 of size 2 was seated
# party 3 of size 7 was seated
# party 4 of size 7 was seated
# party 5 of size 7 was seated
# party 6 of size 6 was seated
# party 7 of size 6 was seated
# party 8 of size 4 was seated
# party 9 of size 4 was seated
# party 10 of size 2 was seated
# party 11 of size 7 was seated
#
# Physical distancing guideline not broken
# Total number of parties seated during timeslot 1: 	11 = 100.00%
# Amount of unoccupied space that can be allocated toward more customers: 247.0m^2
#
#
# Timeslot 2:
#
# party 1 of size 3 was seated
# party 2 of size 8 was seated
# party 3 of size 8 was seated
# party 4 of size 7 was seated
# party 5 of size 6 was seated
# party 6 of size 2 was seated
# party 7 of size 6 was seated
# party 8 of size 5 was seated
# party 9 of size 8 was seated
# party 10 of size 5 was seated
# party 11 of size 8 was seated
# party 12 of size 2 was seated
# party 13 of size 2 was seated
# party 14 of size 8 was seated
# party 15 of size 6 was seated
# party 16 of size 8 was seated
# party 17 of size 2 was seated
#
# Physical distancing guideline not broken
# Total number of parties seated during timeslot 2: 	17 = 100.00%
# Amount of unoccupied space that can be allocated toward more customers: 151.0m^2
#
#
# Timeslot 3:
#
# party 1 of size 2 was seated
# party 2 of size 7 was seated
# party 3 of size 5 was seated
# party 4 of size 5 was seated
# party 5 of size 4 was seated
# party 6 of size 6 was seated
# party 7 of size 5 was seated
# party 8 of size 7 was seated
# party 9 of size 5 was seated
# party 10 of size 7 was seated
# party 11 of size 6 was seated
# party 12 of size 3 was seated
# party 13 of size 3 was seated
# party 14 of size 3 was seated
# party 15 of size 8 was seated
# party 16 of size 4 was seated
# party 17 of size 7 was seated
# party 18 of size 7 was seated
# party 19 of size 5 was seated
# party 20 of size 5 was seated
# party 21 of size 3 was seated
#
# Physical distancing guideline not broken
# Total number of parties seated during timeslot 3: 	21 = 100.00%
# Amount of unoccupied space that can be allocated toward more customers: 91.0m^2
#
#
# Timeslot 4:
#
# party 1 of size 8 was seated
# party 2 of size 7 was seated
# party 3 of size 2 was seated
# party 4 of size 8 was seated
# party 5 of size 2 was seated
# party 6 of size 4 was seated
# party 7 of size 6 was seated
# party 8 of size 6 was seated
# party 9 of size 2 was seated
# party 10 of size 7 was seated
#
# Physical distancing guideline not broken
# Total number of parties seated during timeslot 4: 	10 = 100.00%
# Amount of unoccupied space that can be allocated toward more customers: 259.0m^2
#
#
# Timeslot 5:
#
# party 1 of size 2 was not seated
# party 2 of size 2 was not seated
# party 3 of size 2 was not seated
# party 4 of size 6 was seated
# party 5 of size 8 was seated
# party 6 of size 3 was not seated
# party 7 of size 7 was seated
# party 8 of size 4 was seated
# party 9 of size 5 was seated
# party 10 of size 7 was seated
# party 11 of size 8 was seated
# party 12 of size 8 was seated
# party 13 of size 6 was seated
# party 14 of size 5 was seated
# party 15 of size 5 was seated
# party 16 of size 3 was not seated
# party 17 of size 7 was seated
# party 18 of size 4 was seated
# party 19 of size 6 was seated
# party 20 of size 3 was not seated
# party 21 of size 3 was seated
# party 22 of size 8 was seated
# party 23 of size 8 was seated
# party 24 of size 2 was not seated
# party 25 of size 7 was seated
# party 26 of size 2 was not seated
# party 27 of size 5 was seated
# party 28 of size 5 was seated
# party 29 of size 4 was seated
# party 30 of size 4 was seated
# party 31 of size 4 was seated
# party 32 of size 8 was seated
# party 33 of size 8 was seated
# party 34 of size 4 was seated
# party 35 of size 5 was seated
# party 36 of size 8 was seated
# party 37 of size 4 was seated
# party 38 of size 5 was seated
# party 39 of size 3 was not seated
# party 40 of size 8 was seated
#
# Physical distancing guideline  broken
# Total number of parties seated during timeslot 5: 	31 = 77.50%
# Amount of overoccupied space: 80.0m^2
#
# Amount of unoccupied space that can be allocated toward more customers: 0.0m^2
#
#
# Timeslot 6:
#
# party 1 of size 5 was seated
# party 2 of size 6 was seated
# party 3 of size 3 was seated
# party 4 of size 5 was seated
# party 5 of size 7 was seated
# party 6 of size 4 was seated
# party 7 of size 3 was seated
# party 8 of size 8 was seated
# party 9 of size 4 was seated
# party 10 of size 4 was seated
# party 11 of size 6 was seated
# party 12 of size 7 was seated
# party 13 of size 4 was seated
# party 14 of size 5 was seated
# party 15 of size 5 was seated
# party 16 of size 2 was not seated
# party 17 of size 8 was seated
# party 18 of size 5 was seated
# party 19 of size 6 was seated
# party 20 of size 8 was seated
# party 21 of size 8 was seated
# party 22 of size 4 was seated
# party 23 of size 7 was seated
# party 24 of size 7 was seated
# party 25 of size 6 was seated
# party 26 of size 4 was seated
# party 27 of size 6 was seated
# party 28 of size 7 was seated
# party 29 of size 7 was seated
# party 30 of size 8 was seated
# party 31 of size 3 was seated
# party 32 of size 4 was seated
# party 33 of size 4 was seated
#
# Physical distancing guideline  broken
# Total number of parties seated during timeslot 6: 	32 = 96.97%
# Amount of overoccupied space: 80.0m^2
#
# Amount of unoccupied space that can be allocated toward more customers: 0.0m^2
#
#
# Timeslot 7:
#
# party 1 of size 7 was seated
# party 2 of size 4 was seated
# party 3 of size 6 was seated
# party 4 of size 5 was seated
# party 5 of size 2 was seated
# party 6 of size 6 was seated
# party 7 of size 6 was seated
# party 8 of size 3 was seated
# party 9 of size 8 was seated
# party 10 of size 7 was seated
#
# Physical distancing guideline not broken
# Total number of parties seated during timeslot 7: 	10 = 100.00%
# Amount of unoccupied space that can be allocated toward more customers: 253.0m^2

# %%
m.write("checkModel.lp")
